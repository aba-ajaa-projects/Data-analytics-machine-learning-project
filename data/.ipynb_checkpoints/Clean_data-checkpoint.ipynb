# %%
##import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.2f}'.format

# %%
#import xlsx

dataset = pd.read_excel("C://Users//Ralcaben//Desktop//PROYECTO IRONHACK//data//creditcardmarketing.xlsx")

##check 

dataset
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# ...

# %% [markdown]
# SAVE WITHOUT DATA CLEANING

# %%
dataset.to_excel("C://Users//Ralcaben//Desktop//PROYECTO IRONHACK//data//raw_data.xlsx")

# %% [markdown]
# DATA CLEANING

# %%
##wrong columns
dataset.rename(columns={'# Bank Accounts Open':'Bank Accounts Open', '# Credit Cards Held':'Credit Cards Held','# Homes Owned':'Homes Owned'}, inplace=True)
##drop NaN
dataset = dataset.dropna()
##check
dataset
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        Bank Accounts Open Overdraft Protection Credit Rating  \
# ...

# %%
dataset.describe()
# Out:
#        Customer Number  Bank Accounts Open  Credit Cards Held  Homes Owned  \
# count         17976.00            17976.00           17976.00     17976.00
# mean           8999.73                1.26               1.90         1.20
# std            5196.96                0.47               0.80         0.43
# min               1.00                1.00               1.00         1.00
# 25%            4498.75                1.00               1.00         1.00
# 50%            9000.50                1.00               2.00         1.00
# 75%           13501.25                1.00               2.00         1.00
# max           18000.00                3.00               4.00         3.00
#
#        Household Size  Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  \
# count        17976.00         17976.00    17976.00    17976.00    17976.00
# mean             3.50           940.52      910.45      999.39     1042.03
# ...

# %%
# Specify the name of the excel file
clean_data = 'clean_data.xlsx'
  
# saving the excelsheet
dataset.to_excel("C://Users//Ralcaben//Desktop//PROYECTO IRONHACK//data//clean_data.xlsx")
print('clean_data successfully exported into Excel File')
# Out:
# clean_data successfully exported into Excel File
