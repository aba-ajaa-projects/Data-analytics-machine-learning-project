# %% [markdown]
# # Python Questions - Classification
#
# Create a Jupyter notebook, name it `python_questions.ipynb` to load the data present on file `creditcardmarketing.xlsx` for `credit_card_classification`. Fill the notebook with the Python code needed to answer each question. This last file must be delivered.

# %%
##import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# 1.  Select all the data from table `credit_card_data` to check if the data was imported correctly.

# %%
#import xlsx

dataset = pd.read_excel("C://Users//Ralcaben//Desktop//PROYECTO IRONHACK//data//creditcardmarketing.xlsx")

##check 

dataset
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                         1                   No          High
# 1                         1                   No        Medium
# 2                         2                   No        Medium
# 3                         2                   No          High
# 4                         1                   No        Medium
# ...                     ...                  ...           ...
# 17995                     1                   No           Low
# 17996                     1                   No           Low
# 17997                     1                   No           Low
# 17998                     1                   No        Medium
# 17999                     2                   No        Medium
#
#        # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 0                        2              1               4            No
# 1                        2              2               5           Yes
# 2                        2              1               2           Yes
# 3                        1              1               4            No
# 4                        2              1               6           Yes
# ...                    ...            ...             ...           ...
# 17995                    1              1               5           Yes
# 17996                    3              1               3           Yes
# 17997                    2              1               4            No
# 17998                    4              2               2           Yes
# 17999                    2              1               3            No
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  Q4 Balance
# 0              1160.75     1669.00      877.00     1095.00     1002.00
# 1               147.25       39.00      106.00       78.00      366.00
# 2               276.50      367.00      352.00      145.00      242.00
# 3              1219.00     1578.00     1760.00     1119.00      419.00
# 4              1211.00     2140.00     1357.00      982.00      365.00
# ...                ...         ...         ...         ...         ...
# 17995           167.50      136.00       65.00       71.00      398.00
# 17996           850.50      984.00      940.00      943.00      535.00
# 17997          1087.25      918.00      767.00     1170.00     1494.00
# 17998          1022.25      626.00      983.00      865.00     1615.00
# 17999          1056.00      265.00     1378.00     1978.00      603.00
#
# [18000 rows x 17 columns]

# %% [markdown]
# ##data cleaning & check

# %%
##wrong columns
dataset.rename(columns={'# Bank Accounts Open':'Bank Accounts Open', '# Credit Cards Held':'Credit Cards Held','# Homes Owned':'Homes Owned'}, inplace=True)
##drop NaN
dataset = dataset.dropna()
##check
dataset
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                    1             No  Air Miles      Letter         High
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 3                    4             No  Air Miles      Letter       Medium
# 4                    5             No  Air Miles      Letter       Medium
# ...                ...            ...        ...         ...          ...
# 17995            17996             No  Cash Back      Letter         High
# 17996            17997             No  Cash Back      Letter         High
# 17997            17998             No  Cash Back      Letter         High
# 17998            17999             No  Cash Back      Letter       Medium
# 17999            18000             No  Cash Back      Letter          Low
#
#        Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                       1                   No          High
# 1                       1                   No        Medium
# 2                       2                   No        Medium
# 3                       2                   No          High
# 4                       1                   No        Medium
# ...                   ...                  ...           ...
# 17995                   1                   No           Low
# 17996                   1                   No           Low
# 17997                   1                   No           Low
# 17998                   1                   No        Medium
# 17999                   2                   No        Medium
#
#        Credit Cards Held  Homes Owned  Household Size Own Your Home  \
# 0                      2            1               4            No
# 1                      2            2               5           Yes
# 2                      2            1               2           Yes
# 3                      1            1               4            No
# 4                      2            1               6           Yes
# ...                  ...          ...             ...           ...
# 17995                  1            1               5           Yes
# 17996                  3            1               3           Yes
# 17997                  2            1               4            No
# 17998                  4            2               2           Yes
# 17999                  2            1               3            No
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  Q4 Balance
# 0              1160.75     1669.00      877.00     1095.00     1002.00
# 1               147.25       39.00      106.00       78.00      366.00
# 2               276.50      367.00      352.00      145.00      242.00
# 3              1219.00     1578.00     1760.00     1119.00      419.00
# 4              1211.00     2140.00     1357.00      982.00      365.00
# ...                ...         ...         ...         ...         ...
# 17995           167.50      136.00       65.00       71.00      398.00
# 17996           850.50      984.00      940.00      943.00      535.00
# 17997          1087.25      918.00      767.00     1170.00     1494.00
# 17998          1022.25      626.00      983.00      865.00     1615.00
# 17999          1056.00      265.00     1378.00     1978.00      603.00
#
# [17976 rows x 17 columns]

# %% [markdown]
# 2.  Select all the data from the table to verify if the command worked. Limit your returned results to 10.

# %%
dataset.head(10)
# Out:
#    Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                1             No  Air Miles      Letter         High
# 1                2             No  Air Miles      Letter       Medium
# 2                3             No  Air Miles    Postcard         High
# 3                4             No  Air Miles      Letter       Medium
# 4                5             No  Air Miles      Letter       Medium
# 5                6             No  Air Miles      Letter       Medium
# 6                7             No  Air Miles      Letter       Medium
# 7                8             No  Cash Back    Postcard          Low
# 8                9             No  Air Miles    Postcard       Medium
# 9               10             No  Air Miles      Letter         High
#
#    Bank Accounts Open Overdraft Protection Credit Rating  Credit Cards Held  \
# 0                   1                   No          High                  2
# 1                   1                   No        Medium                  2
# 2                   2                   No        Medium                  2
# 3                   2                   No          High                  1
# 4                   1                   No        Medium                  2
# 5                   1                   No          High                  3
# 6                   1                   No        Medium                  2
# 7                   1                   No        Medium                  4
# 8                   1                   No           Low                  2
# 9                   2                   No           Low                  3
#
#    Homes Owned  Household Size Own Your Home  Average Balance  Q1 Balance  \
# 0            1               4            No          1160.75     1669.00
# 1            2               5           Yes           147.25       39.00
# 2            1               2           Yes           276.50      367.00
# 3            1               4            No          1219.00     1578.00
# 4            1               6           Yes          1211.00     2140.00
# 5            1               4            No          1114.75     1847.00
# 6            1               3            No           283.75      468.00
# 7            1               4           Yes           278.50      132.00
# 8            1               4           Yes          1005.00      894.00
# 9            2               4           Yes           974.25     1814.00
#
#    Q2 Balance  Q3 Balance  Q4 Balance
# 0      877.00     1095.00     1002.00
# 1      106.00       78.00      366.00
# 2      352.00      145.00      242.00
# 3     1760.00     1119.00      419.00
# 4     1357.00      982.00      365.00
# 5     1365.00      750.00      497.00
# 6      188.00      347.00      132.00
# 7      391.00      285.00      306.00
# 8      891.00      882.00     1353.00
# 9     1454.00      514.00      115.00

# %% [markdown]
# 3.  Use code to find how many rows of data you have.

# %%
print('Row count is:',dataset.shape[0])
# Out:
# Row count is: 17976

# %% [markdown]
# 4.  Now find the unique values in some of columns:
#
#     - What are the unique values in the column `Offer Accepted`?
#     - What are the unique values in the column `Reward`?
#     - What are the unique values in the column `Mailer Type`?
#     - What are the unique values in the column `# Credit Cards Held`?
#     - What are the unique values in the column `household_size`?

# %% [markdown]
# - What are the unique values in the column `Offer Accepted`?

# %%
print(dataset['Offer Accepted'].unique())
# Out:
# ['No' 'Yes']

# %% [markdown]
# - What are the unique values in the column `Reward`?

# %%
print(dataset['Reward'].unique())
# Out:
# ['Air Miles' 'Cash Back' 'Points']

# %% [markdown]
# - What are the unique values in the column `Mailer Type`?

# %%
print(dataset['Mailer Type'].unique())
# Out:
# ['Letter' 'Postcard']

# %% [markdown]
# - What are the unique values in the column `# Credit Cards Held`?

# %%
print(dataset['Credit Cards Held'].unique())
# Out:
# [2 1 3 4]

# %% [markdown]
# - What are the unique values in the column `household_size`?

# %%
print(dataset['Household Size'].unique())
# Out:
# [4 5 2 6 3 1 8 9]

# %% [markdown]
# 5.  Arrange the data in decreasing order by the `average_balance`. Return only the `customer_number` of the top 10 customers with the highest `average_balances` in your data.

# %%
dataset_decreasing_order = dataset.sort_values('Average Balance',ascending=False)
dataset_decreasing_order['Customer Number'].head()
# Out:
# 2296      2297
# 12635    12636
# 8887      8888
# 10576    10577
# 14003    14004
# Name: Customer Number, dtype: int64

# %% [markdown]
# 6.  What is the average of `Average Balance` of all the customers in your data?

# %%
mean_dataset = dataset['Average Balance'].mean()
print(mean_dataset)
# Out:
# 940.5155624165554

# %% [markdown]
# 7. In this exercise use  `groupby` to check the properties of some of the categorical variables in our data. Note wherever `average_balance` is asked in the questions below, please take the average of the column `average_balance`. Show the results in a data frame and a plot.
#
#     - What is the average balance of the customers grouped by `Income Level`? The returned result should have only two columns, `Income` and `Average Balance` of the customers.
#     - What is the average balance of the customers grouped by `number_of_bank_accounts_open`? The returned result should have only two columns, `number_of_bank_aaccounts_open` and `Average Balance` of the customers.
#     - What is the average number of credit cards held by customers for each of the credit card ratings? The returned result should have only two columns, `rating` and `average number of credit cards`.
#     - Is there any correlation between the columns `credit_cards_held` and `number_of_bank_accounts_open`? You can analyze this by grouping the data by one of the variables and then aggregating the results of the other column. Visually check if there is a positive correlation or negative correlation or no correlation between the variables.
#     - Check the number of customers in each category (ie number of credit cards held) to assess if that category is well represented in the dataset to include it in your analysis. For eg. If the category is under-represented as compared to other categories, ignore that category in this analysis

# %% [markdown]
# ##What is the average balance of the customers grouped by Income Level? The returned result should have only two columns, Income and Average Balance of the customers.

# %%
dataset.groupby(['Income Level'])['Average Balance'].mean()
# Out:
# Income Level
# High     942.57
# Low      937.66
# Medium   940.89
# Name: Average Balance, dtype: float64

# %% [markdown]
# ##What is the average balance of the customers grouped by number_of_bank_accounts_open? The returned result should have only two columns, number_of_bank_aaccounts_open and Average Balance of the customers.

# %%
dataset.groupby(['Bank Accounts Open'])['Average Balance'].mean()
# Out:
# Bank Accounts Open
# 1   941.53
# 2   936.47
# 3   948.28
# Name: Average Balance, dtype: float64

# %% [markdown]
# ##What is the average number of credit cards held by customers for each of the credit card ratings? The returned result should have only two columns, rating and average number of credit cards.

# %%
dataset.groupby(['Credit Rating'])['Credit Cards Held'].mean()
# Out:
# Credit Rating
# High     1.90
# Low      1.90
# Medium   1.91
# Name: Credit Cards Held, dtype: float64

# %% [markdown]
# #Is there any correlation between the columns credit_cards_held and number_of_bank_accounts_open? You can analyze this by grouping the data by one of the variables and then aggregating the results of the other column. Visually check if there is a positive correlation or negative correlation or no correlation between the variables.

# %%
correlation = dataset.iloc[:,[5,8]]

correlation['sum'] = correlation.sum(axis=1)

print(correlation)
print('there is a positive correlation')
# Out:
#        Bank Accounts Open  Credit Cards Held  sum
# 0                       1                  2    3
# 1                       1                  2    3
# 2                       2                  2    4
# 3                       2                  1    3
# 4                       1                  2    3
# ...                   ...                ...  ...
# 17995                   1                  1    2
# 17996                   1                  3    4
# 17997                   1                  2    3
# 17998                   1                  4    5
# 17999                   2                  2    4
#
# [17976 rows x 3 columns]
# there is a positive correlation
# C:\Users\Ralcaben\AppData\Local\Temp/ipykernel_18848/834043416.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   correlation['sum'] = correlation.sum(axis=1)

# %% [markdown]
# ##Check the number of customers in each category (ie number of credit cards held) to assess if that category is well represented in the dataset to include it in your analysis. For eg. If the category is under-represented as compared to other categories, ignore that category in this analysis

# %%
freq = dataset['Credit Cards Held'].value_counts() 
print(freq)
# Out:
# 2    7933
# 1    6147
# 3    3381
# 4     515
# Name: Credit Cards Held, dtype: int64

# %% [markdown]
# 8. Your managers are only interested in the customers with the following properties:
#
#     - Credit rating medium or high
#     - Credit cards held 2 or less
#     - Owns their own home
#     - Household size 3 or more
#
#     For the rest of the things, they are not too concerned. Write code to find what are the options available for them.
#
#     Can you filter the customers who accepted the offers here?

# %%
cleaning_dataset = dataset

cleaning_dataset = cleaning_dataset.drop(cleaning_dataset[cleaning_dataset['Credit Rating']=='Low'].index)
cleaning_dataset = cleaning_dataset.drop(cleaning_dataset[cleaning_dataset['Credit Cards Held']>2].index)
cleaning_dataset = cleaning_dataset.drop(cleaning_dataset[cleaning_dataset['Own Your Home']=='No'].index)
cleaning_dataset = cleaning_dataset.drop(cleaning_dataset[cleaning_dataset['Credit Cards Held']>=3].index)


cleaning_dataset
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 1                    2             No  Air Miles      Letter       Medium
# 2                    3             No  Air Miles    Postcard         High
# 4                    5             No  Air Miles      Letter       Medium
# 16                  17             No     Points    Postcard          Low
# 17                  18             No  Air Miles    Postcard          Low
# ...                ...            ...        ...         ...          ...
# 17985            17986             No     Points    Postcard       Medium
# 17986            17987             No     Points      Letter         High
# 17987            17988             No     Points      Letter         High
# 17988            17989             No  Air Miles      Letter       Medium
# 17990            17991             No  Air Miles      Letter       Medium
#
#        Bank Accounts Open Overdraft Protection Credit Rating  \
# 1                       1                   No        Medium
# 2                       2                   No        Medium
# 4                       1                   No        Medium
# 16                      2                   No        Medium
# 17                      2                   No          High
# ...                   ...                  ...           ...
# 17985                   1                   No        Medium
# 17986                   1                   No          High
# 17987                   1                   No        Medium
# 17988                   1                  Yes        Medium
# 17990                   1                   No          High
#
#        Credit Cards Held  Homes Owned  Household Size Own Your Home  \
# 1                      2            2               5           Yes
# 2                      2            1               2           Yes
# 4                      2            1               6           Yes
# 16                     1            1               4           Yes
# 17                     2            1               4           Yes
# ...                  ...          ...             ...           ...
# 17985                  1            1               5           Yes
# 17986                  2            1               3           Yes
# 17987                  1            1               5           Yes
# 17988                  1            1               2           Yes
# 17990                  1            1               3           Yes
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  Q4 Balance
# 1               147.25       39.00      106.00       78.00      366.00
# 2               276.50      367.00      352.00      145.00      242.00
# 4              1211.00     2140.00     1357.00      982.00      365.00
# 16             1217.00      567.00     1161.00      966.00     2174.00
# 17             1185.25      272.00     1523.00     2042.00      904.00
# ...                ...         ...         ...         ...         ...
# 17985          1022.75     1391.00     1660.00      647.00      393.00
# 17986           943.25     1583.00     1001.00      818.00      371.00
# 17987           943.00     1845.00     1015.00      684.00      228.00
# 17988           911.00      639.00     1209.00     1271.00      525.00
# 17990           335.75      447.00      378.00      274.00      244.00
#
# [6123 rows x 17 columns]

# %% [markdown]
# Can you filter the customers who accepted the offers here?

# %%
cleaning_dataset[cleaning_dataset['Offer Accepted']=='Yes']
# Out:
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 50                  51            Yes  Air Miles    Postcard          Low
# 57                  58            Yes  Air Miles    Postcard          Low
# 112                113            Yes  Air Miles      Letter         High
# 131                132            Yes  Air Miles    Postcard         High
# 250                251            Yes  Air Miles      Letter         High
# ...                ...            ...        ...         ...          ...
# 17841            17842            Yes  Air Miles    Postcard          Low
# 17903            17904            Yes     Points    Postcard          Low
# 17931            17932            Yes     Points      Letter       Medium
# 17942            17943            Yes  Air Miles    Postcard          Low
# 17971            17972            Yes  Cash Back    Postcard          Low
#
#        Bank Accounts Open Overdraft Protection Credit Rating  \
# 50                      1                   No          High
# 57                      1                   No        Medium
# 112                     1                  Yes          High
# 131                     2                   No        Medium
# 250                     1                   No        Medium
# ...                   ...                  ...           ...
# 17841                   1                   No          High
# 17903                   2                   No        Medium
# 17931                   1                   No          High
# 17942                   1                   No        Medium
# 17971                   1                   No          High
#
#        Credit Cards Held  Homes Owned  Household Size Own Your Home  \
# 50                     2            1               2           Yes
# 57                     1            1               2           Yes
# 112                    2            1               5           Yes
# 131                    2            2               3           Yes
# 250                    1            1               5           Yes
# ...                  ...          ...             ...           ...
# 17841                  2            1               3           Yes
# 17903                  1            1               4           Yes
# 17931                  2            1               5           Yes
# 17942                  1            1               3           Yes
# 17971                  2            2               4           Yes
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  Q4 Balance
# 50              931.75     1536.00     1232.00      597.00      362.00
# 57             1192.75     1787.00      908.00     1343.00      733.00
# 112            1082.50     1890.00     1405.00      996.00       39.00
# 131             811.50      820.00      958.00      564.00      904.00
# 250            1047.75      438.00      762.00     1014.00     1977.00
# ...                ...         ...         ...         ...         ...
# 17841           881.25      878.00      871.00      808.00      968.00
# 17903          1038.00      275.00      510.00     1493.00     1874.00
# 17931          1539.00     1423.00     1864.00     1527.00     1342.00
# 17942          1026.25      297.00     1672.00     1569.00      567.00
# 17971          1221.75     2118.00     1632.00     1029.00      108.00
#
# [207 rows x 17 columns]

# %% [markdown]
# 9. Your managers want to find out the list of customers whose average balance is less than the average balance of all the customers in the database. Write a query to show them the list of such customers.

# %%
mean_cleaning = cleaning_dataset['Average Balance'].mean()

print("The mean is: ",mean_cleaning)

cleaning_dataset[(cleaning_dataset['Average Balance'] > mean_cleaning)]
# Out:
# The mean is:  943.4935897435897
#        Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 4                    5             No  Air Miles      Letter       Medium
# 16                  17             No     Points    Postcard          Low
# 17                  18             No  Air Miles    Postcard          Low
# 19                  20             No  Cash Back      Letter       Medium
# 20                  21             No     Points    Postcard          Low
# ...                ...            ...        ...         ...          ...
# 17967            17968             No     Points    Postcard          Low
# 17971            17972            Yes  Cash Back    Postcard          Low
# 17980            17981             No  Air Miles    Postcard       Medium
# 17981            17982             No  Cash Back      Letter          Low
# 17985            17986             No     Points    Postcard       Medium
#
#        Bank Accounts Open Overdraft Protection Credit Rating  \
# 4                       1                   No        Medium
# 16                      2                   No        Medium
# 17                      2                   No          High
# 19                      1                   No          High
# 20                      1                   No          High
# ...                   ...                  ...           ...
# 17967                   1                   No          High
# 17971                   1                   No          High
# 17980                   1                   No          High
# 17981                   2                  Yes        Medium
# 17985                   1                   No        Medium
#
#        Credit Cards Held  Homes Owned  Household Size Own Your Home  \
# 4                      2            1               6           Yes
# 16                     1            1               4           Yes
# 17                     2            1               4           Yes
# 19                     2            1               5           Yes
# 20                     2            1               4           Yes
# ...                  ...          ...             ...           ...
# 17967                  2            2               3           Yes
# 17971                  2            2               4           Yes
# 17980                  1            1               5           Yes
# 17981                  2            1               2           Yes
# 17985                  1            1               5           Yes
#
#        Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  Q4 Balance
# 4              1211.00     2140.00     1357.00      982.00      365.00
# 16             1217.00      567.00     1161.00      966.00     2174.00
# 17             1185.25      272.00     1523.00     2042.00      904.00
# 19             1086.75      764.00      997.00      921.00     1665.00
# 20             1175.25     1234.00     1102.00     1423.00      942.00
# ...                ...         ...         ...         ...         ...
# 17967          1063.00      188.00      742.00     1134.00     2188.00
# 17971          1221.75     2118.00     1632.00     1029.00      108.00
# 17980          1462.00     1429.00     1496.00     1428.00     1495.00
# 17981          1016.25      360.00      810.00     1537.00     1358.00
# 17985          1022.75     1391.00     1660.00      647.00      393.00
#
# [3735 rows x 17 columns]

# %% [markdown]
# 10. What is the number of people who accepted the offer vs the number of people who did not?

# %%
print('Row count is:',cleaning_dataset.shape[0])

yess = cleaning_dataset[(cleaning_dataset['Offer Accepted'] == 'Yes')].shape[0]
noo = cleaning_dataset[(cleaning_dataset['Offer Accepted'] == 'No')].shape[0]

print("Who accepted: ",yess)
print("Who did not: ",noo)

##check result
yess + noo == cleaning_dataset.shape[0]
# Out:
# Row count is: 6123
# Who accepted:  207
# Who did not:  5916
# True

# %% [markdown]
# 11. Your managers are more interested in customers with a credit rating of high or medium. What is the difference in average balances of the customers with high credit card rating and low credit card rating?

# %%
difference_dataset = dataset

highh = difference_dataset[(difference_dataset['Credit Rating'] == 'High')].mean()
loww = difference_dataset[(difference_dataset['Credit Rating'] == 'Low')].mean()

x = highh - loww
print(x)
# Out:
# Customer Number      -52.26
# Bank Accounts Open    -0.02
# Credit Cards Held     -0.01
# Homes Owned            0.00
# Household Size        -0.02
# Average Balance        4.05
# Q1 Balance            25.42
# Q2 Balance            -5.13
# Q3 Balance           -10.78
# Q4 Balance             6.69
# dtype: float64
# C:\Users\Ralcaben\AppData\Local\Temp/ipykernel_18848/125304045.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   highh = difference_dataset[(difference_dataset['Credit Rating'] == 'High')].mean()
# C:\Users\Ralcaben\AppData\Local\Temp/ipykernel_18848/125304045.py:4: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   loww = difference_dataset[(difference_dataset['Credit Rating'] == 'Low')].mean()

# %% [markdown]
# 12. In the database, which all types of communication (`Mailer Type`) were used and with how many customers?

# %%
print(dataset['Mailer Type'].unique())

print('All customers:',dataset.shape[0])

Letter = dataset[(dataset['Mailer Type'] == 'Letter')].shape[0]
Postcard = dataset[(dataset['Mailer Type'] == 'Postcard')].shape[0]

print("Mailer type letter: ",Letter)
print("Mailer type postcard: ",Postcard)
# Out:
# ['Letter' 'Postcard']
# All customers: 17976
# Mailer type letter:  8842
# Mailer type postcard:  9134

# %% [markdown]
# 13. Provide the details of the customer that is the 11th least `Q1_balance` in your database.

# %%
elevenleast = dataset.sort_values('Q1 Balance',ascending=False)
elevenleast.iloc[-11]
# Out:
# Customer Number              4172
# Offer Accepted                 No
# Reward                  Cash Back
# Mailer Type              Postcard
# Income Level                  Low
# Bank Accounts Open              1
# Overdraft Protection           No
# Credit Rating              Medium
# Credit Cards Held               1
# Homes Owned                     1
# Household Size                  3
# Own Your Home                 Yes
# Average Balance             79.50
# Q1 Balance                   1.00
# Q2 Balance                  38.00
# Q3 Balance                  83.00
# Q4 Balance                 196.00
# Name: 4171, dtype: object
